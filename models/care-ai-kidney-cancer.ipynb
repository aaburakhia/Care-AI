# %%
# ==================================================================================
# KIDNEY CANCER CLASSIFICATION WITH PROPER SAVING AND ONNX CONVERSION
# ==================================================================================

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
import warnings
warnings.filterwarnings('ignore')

np.random.seed(42)
tf.random.set_seed(42)

# ==================================================================================
# CONFIGURATION
# ==================================================================================

DATASET_ROOT = '/kaggle/input/multi-cancer/Multi Cancer/Multi Cancer'
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
LEARNING_RATE = 1e-4

CANCER_CONFIGS = {
    'Kidney_Cancer': {
        'folder': 'Kidney Cancer',
        'classes': ['kidney_normal', 'kidney_tumor'],
        'class_names': ['Normal', 'Tumor']
    }
}

# ==================================================================================
# DATA LOADING AND PREPROCESSING
# ==================================================================================

def load_kidney_cancer_data():
    """Load and prepare Kidney Cancer dataset"""
    config = CANCER_CONFIGS['Kidney_Cancer']
    data_dir = os.path.join(DATASET_ROOT, config['folder'])
    
    # Create dataset
    train_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset="training",
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode='categorical'
    )
    
    val_ds = tf.keras.utils.image_dataset_from_directory(
        data_dir,
        validation_split=0.2,
        subset="validation",
        seed=42,
        image_size=IMG_SIZE,
        batch_size=BATCH_SIZE,
        label_mode='categorical'
    )
    
    # Optimize performance
    AUTOTUNE = tf.data.AUTOTUNE
    train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
    val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
    
    return train_ds, val_ds, config['class_names']

# Load data
print("Loading Kidney Cancer dataset...")
train_ds, val_ds, class_names = load_kidney_cancer_data()
print(f"Classes: {class_names}")

# ==================================================================================
# MODEL ARCHITECTURE
# ==================================================================================

def create_kidney_cancer_model(num_classes=2):
    """Create EfficientNetB3-based model for kidney cancer classification"""
    
    base_model = EfficientNetB3(
        include_top=False,
        weights='imagenet',
        input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)
    )
    
    # Freeze base model initially
    base_model.trainable = False
    
    # Build model
    inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    model = keras.Model(inputs, outputs, name='kidney_cancer_classifier')
    
    return model

# Create model
print("Creating model...")
model = create_kidney_cancer_model(num_classes=len(class_names))
model.summary()

# ==================================================================================
# TRAINING
# ==================================================================================

# Compile model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.AUC(name='auc')]
)

# Callbacks
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=3,
        min_lr=1e-7,
        verbose=1
    )
]

# Train model
print("Training model...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks,
    verbose=1
)

# ==================================================================================
# EVALUATION
# ==================================================================================

def plot_training_history(history):
    """Plot training history"""
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    
    # Accuracy
    axes[0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    axes[0].set_title('Model Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].legend()
    axes[0].grid(True)
    
    # Loss
    axes[1].plot(history.history['loss'], label='Train Loss')
    axes[1].plot(history.history['val_loss'], label='Val Loss')
    axes[1].set_title('Model Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].legend()
    axes[1].grid(True)
    
    # AUC
    axes[2].plot(history.history['auc'], label='Train AUC')
    axes[2].plot(history.history['val_auc'], label='Val AUC')
    axes[2].set_title('Model AUC')
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('AUC')
    axes[2].legend()
    axes[2].grid(True)
    
    plt.tight_layout()
    plt.savefig('kidney_training_history.png', dpi=300, bbox_inches='tight')
    plt.show()

# Plot training history
plot_training_history(history)

# Evaluate on validation set
print("\nEvaluating model...")
val_loss, val_accuracy, val_auc = model.evaluate(val_ds)
print(f"Validation Loss: {val_loss:.4f}")
print(f"Validation Accuracy: {val_accuracy:.4f}")
print(f"Validation AUC: {val_auc:.4f}")

# ==================================================================================
# CONFUSION MATRIX AND CLASSIFICATION REPORT
# ==================================================================================

# Get predictions
y_true = []
y_pred = []
y_pred_proba = []

for images, labels in val_ds:
    predictions = model.predict(images, verbose=0)
    y_pred_proba.extend(predictions)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_names, yticklabels=class_names)
plt.title('Kidney Cancer - Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig('kidney_confusion_matrix.png', dpi=300, bbox_inches='tight')
plt.show()

# Classification Report
print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=class_names))

# ROC Curve
if len(class_names) == 2:
    fpr, tpr, _ = roc_curve(y_true, np.array(y_pred_proba)[:, 1])
    auc_score = roc_auc_score(y_true, np.array(y_pred_proba)[:, 1])
    
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, label=f'ROC Curve (AUC = {auc_score:.4f})')
    plt.plot([0, 1], [0, 1], 'k--', label='Random Classifier')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Kidney Cancer - ROC Curve')
    plt.legend()
    plt.grid(True)
    plt.savefig('kidney_roc_curve.png', dpi=300, bbox_inches='tight')
    plt.show()

# ==================================================================================
# SAVE MODEL IN MULTIPLE FORMATS
# ==================================================================================

print("\n" + "="*80)
print("SAVING MODELS")
print("="*80)

# 1. Save in Keras format (.keras) - Recommended TF 2.x format
keras_model_path = 'kidney_cancer_model.keras'
model.save(keras_model_path)
print(f"✓ Saved Keras model: {keras_model_path}")

# 2. Save in H5 format (legacy)
h5_model_path = 'kidney_cancer_model.h5'
model.save(h5_model_path)
print(f"✓ Saved H5 model: {h5_model_path}")

# 3. Save in SavedModel format (Keras 3 compatible)
savedmodel_path = 'kidney_cancer_savedmodel'
tf.saved_model.save(model, savedmodel_path)
print(f"✓ Saved TensorFlow SavedModel: {savedmodel_path}")

# ==================================================================================
# CONVERT TO ONNX FORMAT
# ==================================================================================

print("\n" + "="*80)
print("CONVERTING TO ONNX FORMAT")
print("="*80)

# Install tf2onnx if not already installed
import subprocess
import sys

try:
    import tf2onnx
    import onnx
    print("✓ tf2onnx and onnx already installed")
except ImportError:
    print("Installing tf2onnx and onnx...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "tf2onnx", "onnx"])
    import tf2onnx
    import onnx
    print("✓ tf2onnx and onnx installed successfully")

# Convert to ONNX
onnx_model_path = 'kidney_cancer_model.onnx'

print(f"\nConverting model to ONNX format...")
print(f"Input shape: {model.input_shape}")

# Method 1: Convert from Keras model directly
input_signature = [tf.TensorSpec(shape=model.input_shape, dtype=tf.float32, name='input')]
onnx_model, _ = tf2onnx.convert.from_keras(model, input_signature, opset=15)
onnx.save(onnx_model, onnx_model_path)
print(f"✓ Saved ONNX model: {onnx_model_path}")

# Verify ONNX model
print(f"\nVerifying ONNX model...")
onnx_model_check = onnx.load(onnx_model_path)
onnx.checker.check_model(onnx_model_check)
print("✓ ONNX model is valid!")

# Get model info
print(f"\nONNX Model Information:")
print(f"  - IR Version: {onnx_model_check.ir_version}")
print(f"  - Producer: {onnx_model_check.producer_name}")
print(f"  - Opset: {onnx_model_check.opset_import[0].version}")
print(f"  - Input: {onnx_model_check.graph.input[0].name}")
print(f"  - Output: {onnx_model_check.graph.output[0].name}")

# ==================================================================================
# TEST ONNX MODEL
# ==================================================================================

print("\n" + "="*80)
print("TESTING ONNX MODEL")
print("="*80)

try:
    import onnxruntime as ort
    print("✓ onnxruntime already installed")
except ImportError:
    print("Installing onnxruntime...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "onnxruntime"])
    import onnxruntime as ort
    print("✓ onnxruntime installed successfully")

# Create ONNX Runtime session
ort_session = ort.InferenceSession(onnx_model_path, providers=['CPUExecutionProvider'])

# Get a sample batch from validation set
for sample_images, sample_labels in val_ds.take(1):
    # Test with Keras model
    keras_predictions = model.predict(sample_images, verbose=0)
    
    # Test with ONNX model
    onnx_inputs = {ort_session.get_inputs()[0].name: sample_images.numpy()}
    onnx_predictions = ort_session.run(None, onnx_inputs)[0]
    
    # Compare predictions
    print(f"\nComparing Keras vs ONNX predictions:")
    print(f"Keras prediction shape: {keras_predictions.shape}")
    print(f"ONNX prediction shape: {onnx_predictions.shape}")
    print(f"Max difference: {np.max(np.abs(keras_predictions - onnx_predictions)):.8f}")
    
    if np.allclose(keras_predictions, onnx_predictions, atol=1e-4):
        print("✓ ONNX predictions match Keras predictions!")
    else:
        print("⚠ Warning: Small differences detected (this is normal due to numerical precision)")

# ==================================================================================
# SAVE METADATA AND CLASS INFORMATION
# ==================================================================================

import json

metadata = {
    'model_name': 'kidney_cancer_classifier',
    'cancer_type': 'Kidney Cancer',
    'classes': class_names,
    'num_classes': len(class_names),
    'input_shape': list(model.input_shape[1:]),
    'img_size': IMG_SIZE,
    'model_architecture': 'EfficientNetB3',
    'validation_accuracy': float(val_accuracy),
    'validation_auc': float(val_auc),
    'validation_loss': float(val_loss),
    'preprocessing': 'Rescaling to [0, 1]',
    'onnx_opset': 15
}

with open('kidney_cancer_metadata.json', 'w') as f:
    json.dump(metadata, f, indent=4)

print(f"\n✓ Saved metadata: kidney_cancer_metadata.json")

# ==================================================================================
# SUMMARY
# ==================================================================================

print("\n" + "="*80)
print("MODEL TRAINING AND EXPORT COMPLETE")
print("="*80)
print(f"\nFiles saved:")
print(f"  1. kidney_cancer_model.keras - Keras format (recommended)")
print(f"  2. kidney_cancer_model.h5 - H5 format (legacy)")
print(f"  3. kidney_cancer_savedmodel/ - TensorFlow SavedModel format")
print(f"  4. kidney_cancer_model.onnx - ONNX format (for deployment)")
print(f"  5. kidney_cancer_metadata.json - Model metadata")
print(f"\nModel Performance:")
print(f"  - Validation Accuracy: {val_accuracy:.4f}")
print(f"  - Validation AUC: {val_auc:.4f}")
print(f"  - Validation Loss: {val_loss:.4f}")
print(f"\nNext steps:")
print(f"  1. Upload 'kidney_cancer_model.onnx' to Hugging Face")
print(f"  2. Upload 'kidney_cancer_metadata.json' for reference")
print(f"  3. Use ONNX model in your Streamlit app with onnxruntime")
print("="*80)
# Out:
# Loading Kidney Cancer dataset...
# Found 10000 files belonging to 2 classes.
# Using 8000 files for training.
# Found 10000 files belonging to 2 classes.
# Using 2000 files for validation.
# Classes: ['Normal', 'Tumor']
# Creating model...
# Model: "kidney_cancer_classifier"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb3 (Functional)     │ (None, 7, 7, 1536)     │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1536)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       393,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,177,521 (42.64 MB)
#  Trainable params: 393,986 (1.50 MB)
#  Non-trainable params: 10,783,535 (41.14 MB)
# Training model...
# Epoch 1/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 76s 128ms/step - accuracy: 0.8221 - auc: 0.8912 - loss: 0.4091 - val_accuracy: 0.9695 - val_auc: 0.9958 - val_loss: 0.1150 - learning_rate: 1.0000e-04
# Epoch 2/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9530 - auc: 0.9911 - loss: 0.1404 - val_accuracy: 0.9825 - val_auc: 0.9988 - val_loss: 0.0664 - learning_rate: 1.0000e-04
# Epoch 3/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9714 - auc: 0.9960 - loss: 0.0915 - val_accuracy: 0.9905 - val_auc: 0.9996 - val_loss: 0.0417 - learning_rate: 1.0000e-04
# Epoch 4/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9739 - auc: 0.9974 - loss: 0.0749 - val_accuracy: 0.9930 - val_auc: 0.9998 - val_loss: 0.0300 - learning_rate: 1.0000e-04
# Epoch 5/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9820 - auc: 0.9982 - loss: 0.0598 - val_accuracy: 0.9945 - val_auc: 0.9998 - val_loss: 0.0265 - learning_rate: 1.0000e-04
# Epoch 6/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9859 - auc: 0.9989 - loss: 0.0496 - val_accuracy: 0.9965 - val_auc: 0.9999 - val_loss: 0.0185 - learning_rate: 1.0000e-04
# Epoch 7/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9884 - auc: 0.9992 - loss: 0.0414 - val_accuracy: 0.9975 - val_auc: 1.0000 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 8/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9879 - auc: 0.9993 - loss: 0.0379 - val_accuracy: 0.9980 - val_auc: 1.0000 - val_loss: 0.0121 - learning_rate: 1.0000e-04
# Epoch 9/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9887 - auc: 0.9992 - loss: 0.0388 - val_accuracy: 0.9980 - val_auc: 1.0000 - val_loss: 0.0115 - learning_rate: 1.0000e-04
# Epoch 10/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9924 - auc: 0.9997 - loss: 0.0301 - val_accuracy: 0.9975 - val_auc: 1.0000 - val_loss: 0.0126 - learning_rate: 1.0000e-04
# Epoch 11/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9933 - auc: 0.9997 - loss: 0.0247 - val_accuracy: 0.9975 - val_auc: 1.0000 - val_loss: 0.0117 - learning_rate: 1.0000e-04
# Epoch 12/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9938 - auc: 0.9998 - loss: 0.0226 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_loss: 0.0074 - learning_rate: 1.0000e-04
# Epoch 13/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9910 - auc: 0.9995 - loss: 0.0262 - val_accuracy: 0.9980 - val_auc: 1.0000 - val_loss: 0.0081 - learning_rate: 1.0000e-04
# Epoch 14/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9922 - auc: 0.9998 - loss: 0.0225 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_loss: 0.0066 - learning_rate: 1.0000e-04
# Epoch 15/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 59ms/step - accuracy: 0.9932 - auc: 0.9994 - loss: 0.0242 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0045 - learning_rate: 1.0000e-04
# Epoch 16/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.0196 - val_accuracy: 0.9985 - val_auc: 1.0000 - val_loss: 0.0050 - learning_rate: 1.0000e-04
# Epoch 17/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9936 - auc: 0.9999 - loss: 0.0180 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0038 - learning_rate: 1.0000e-04
# Epoch 18/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9958 - auc: 0.9998 - loss: 0.0160 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0038 - learning_rate: 1.0000e-04
# Epoch 19/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 60ms/step - accuracy: 0.9959 - auc: 0.9998 - loss: 0.0164 - val_accuracy: 0.9995 - val_auc: 1.0000 - val_loss: 0.0030 - learning_rate: 1.0000e-04
# Epoch 20/20
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 15s 58ms/step - accuracy: 0.9960 - auc: 0.9999 - loss: 0.0157 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0031 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 19.
# Evaluating model...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0046
# Validation Loss: 0.0030
# Validation Accuracy: 0.9995
# Validation AUC: 1.0000
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       980
#        Tumor       1.00      1.00      1.00      1020
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
# ================================================================================
# SAVING MODELS
# ================================================================================
# ✓ Saved Keras model: kidney_cancer_model.keras
# ✓ Saved H5 model: kidney_cancer_model.h5
# ✓ Saved TensorFlow SavedModel: kidney_cancer_savedmodel
#
# ================================================================================
# CONVERTING TO ONNX FORMAT
# ================================================================================
# Installing tf2onnx and onnx...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 93.0 MB/s eta 0:00:00
# ✓ tf2onnx and onnx installed successfully
#
# Converting model to ONNX format...
# Input shape: (None, 224, 224, 3)
# I0000 00:00:1761661055.863633      36 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761661055.863841      36 single_machine.cc:361] Starting new session
# I0000 00:00:1761661055.864975      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# I0000 00:00:1761661063.180495      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# I0000 00:00:1761661066.437005      36 devices.cc:67] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 1
# I0000 00:00:1761661066.437257      36 single_machine.cc:361] Starting new session
# I0000 00:00:1761661066.438415      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# ✓ Saved ONNX model: kidney_cancer_model.onnx
#
# Verifying ONNX model...
# ✓ ONNX model is valid!
#
# ONNX Model Information:
#   - IR Version: 8
#   - Producer: tf2onnx
#   - Opset: 15
#   - Input: input
#   - Output: dense_3
#
# ================================================================================
# TESTING ONNX MODEL
# ================================================================================
# Installing onnxruntime...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
# ✓ onnxruntime installed successfully
#
# Comparing Keras vs ONNX predictions:
# Keras prediction shape: (32, 2)
# ONNX prediction shape: (32, 2)
# Max difference: 0.00000003
# ✓ ONNX predictions match Keras predictions!
#
# ✓ Saved metadata: kidney_cancer_metadata.json
#
# ================================================================================
# MODEL TRAINING AND EXPORT COMPLETE
# ================================================================================
#
# Files saved:
#   1. kidney_cancer_model.keras - Keras format (recommended)
#   2. kidney_cancer_model.h5 - H5 format (legacy)
#   3. kidney_cancer_savedmodel/ - TensorFlow SavedModel format
#   4. kidney_cancer_model.onnx - ONNX format (for deployment)
#   5. kidney_cancer_metadata.json - Model metadata
#
# Model Performance:
#   - Validation Accuracy: 0.9995
#   - Validation AUC: 1.0000
#   - Validation Loss: 0.0030
#
# Next steps:
#   1. Upload 'kidney_cancer_model.onnx' to Hugging Face
#   2. Upload 'kidney_cancer_metadata.json' for reference
#   3. Use ONNX model in your Streamlit app with onnxruntime
# ================================================================================
